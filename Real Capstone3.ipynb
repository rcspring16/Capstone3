# %%
import pandas as pd

# %%
deaths_df = pd.read_csv("all_deaths.csv")

# %%
jails_df = pd.read_csv("all_jails.csv")

# %%
df['med2008'] = df.med2008.str.replace(r'(^.*/.*$)', 'transition')
df['med2009'] = df.med2009.str.replace(r'(^.*/.*$)', 'transition')
df['med2010'] = df.med2010.str.replace(r'(^.*/.*$)', 'transition')
df['med2011'] = df.med2011.str.replace(r'(^.*/.*$)', 'transition')
df['med2012'] = df.med2012.str.replace(r'(^.*/.*$)', 'transition')
df['med2013'] = df.med2013.str.replace(r'(^.*/.*$)', 'transition')
df['med2014'] = df.med2014.str.replace(r'(^.*/.*$)', 'transition')
df['med2015'] = df.med2015.str.replace(r'(^.*/.*$)', 'transition')
df['med2016'] = df.med2016.str.replace(r'(^.*/.*$)', 'transition')
df['med2017'] = df.med2017.str.replace(r'(^.*/.*$)', 'transition')
df['med2018'] = df.med2018.str.replace(r'(^.*/.*$)', 'transition')
df['med2019'] = df.med2019.str.replace(r'(^.*/.*$)', 'transition')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-136-ef95d3f38d0f> in <module>
# ----> 1 df['med2008'] = df.med2008.str.replace(r'(^.*/.*$)', 'transition')
#       2 df['med2009'] = df.med2009.str.replace(r'(^.*/.*$)', 'transition')
#       3 df['med2010'] = df.med2010.str.replace(r'(^.*/.*$)', 'transition')
#       4 df['med2011'] = df.med2011.str.replace(r'(^.*/.*$)', 'transition')
#       5 df['med2012'] = df.med2012.str.replace(r'(^.*/.*$)', 'transition')
#
# AttributeError: 'function' object has no attribute 'med2008'

# %%
df.head(30)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-137-3333f10a9e03> in <module>
# ----> 1 df.head(30)
#
# AttributeError: 'function' object has no attribute 'head'

# %%
import numpy as np

# %%
df['med2008'] = np.where(~df['med2008'].str.contains(("public","transition")), "private", df['med2008'])
df['med2009'] = np.where(~df['med2009'].str.contains(("public","transition")), "private", df['med2009'])
df['med2010'] = np.where(~df['med2010'].str.contains(("public","transition")), "private", df['med2010'])
df['med2011'] = np.where(~df['med2011'].str.contains(("public","transition")), "private", df['med2011'])
df['med2012'] = np.where(~df['med2012'].str.contains(("public","transition")), "private", df['med2012'])
df['med2013'] = np.where(~df['med2013'].str.contains(("public","transition")), "private", df['med2013'])
df['med2014'] = np.where(~df['med2014'].str.contains(("public","transition")), "private", df['med2014'])
df['med2015'] = np.where(~df['med2015'].str.contains(("public","transition")), "private", df['med2015'])
df['med2016'] = np.where(~df['med2016'].str.contains(("public","transition")), "private", df['med2016'])
df['med2017'] = np.where(~df['med2017'].str.contains(("public","transition")), "private", df['med2017'])
df['med2018'] = np.where(~df['med2018'].str.contains(("public","transition")), "private", df['med2018'])
df['med2019'] = np.where(~df['med2019'].str.contains(("public","transition")), "private", df['med2019'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-134-1e9c814434c3> in <module>
# ----> 1 df['med2008'] = np.where(~df['med2008'].str.contains(("public","transition")), "private", df['med2008'])
#       2 df['med2009'] = np.where(~df['med2009'].str.contains(("public","transition")), "private", df['med2009'])
#       3 df['med2010'] = np.where(~df['med2010'].str.contains(("public","transition")), "private", df['med2010'])
#       4 df['med2011'] = np.where(~df['med2011'].str.contains(("public","transition")), "private", df['med2011'])
#       5 df['med2012'] = np.where(~df['med2012'].str.contains(("public","transition")), "private", df['med2012'])
#
# ~/.pyenv/versions/3.9.1/lib/python3.9/site-packages/pandas/core/strings/accessor.py in wrapper(self, *args, **kwargs)
#      99                 )
#     100                 raise TypeError(msg)
# --> 101             return func(self, *args, **kwargs)
#     102
#     103         wrapper.__name__ = func_name
#
# ~/.pyenv/versions/3.9.1/lib/python3.9/site-packages/pandas/core/strings/accessor.py in contains(self, pat, case, flags, na, regex)
#    1108         dtype: bool
#    1109         """
# -> 1110         result = self._data.array._str_contains(pat, case, flags, na, regex)
#    1111         return self._wrap_result(result, fill_value=na, returns_string=False)
#    1112
#
# ~/.pyenv/versions/3.9.1/lib/python3.9/site-packages/pandas/core/strings/object_array.py in _str_contains(self, pat, case, flags, na, regex)
#     108                 flags |= re.IGNORECASE
#     109
# --> 110             regex = re.compile(pat, flags=flags)
#     111
#     112             if regex.groups > 0:
#
# ~/.pyenv/versions/3.9.1/lib/python3.9/re.py in compile(pattern, flags)
#     250 def compile(pattern, flags=0):
#     251     "Compile a regular expression pattern, returning a Pattern object."
# --> 252     return _compile(pattern, flags)
#     253
#     254 def purge():
#
# ~/.pyenv/versions/3.9.1/lib/python3.9/re.py in _compile(pattern, flags)
#     301         return pattern
#     302     if not sre_compile.isstring(pattern):
# --> 303         raise TypeError("first argument must be string or compiled pattern")
#     304     p = sre_compile.compile(pattern, flags)
#     305     if not (flags & DEBUG):
#
# TypeError: first argument must be string or compiled pattern

# %%
df.head(28)
# Out:
#     id    fips statecode     state state_notes      county  \
# 0    1  1003.0        AL   Alabama         NaN     Baldwin
# 1    2  1015.0        AL   Alabama         NaN     Calhoun
# 2    3  1055.0        AL   Alabama         NaN      Etowah
# 3    4  1069.0        AL   Alabama         NaN     Houston
# 4    5  1073.0        AL   Alabama         NaN   Jefferson
# 5   13  1081.0        AL   Alabama         NaN         Lee
# 6    7  1089.0        AL   Alabama         NaN     Madison
# 7    8  1095.0        AL   Alabama         NaN    Marshall
# 8    9  1097.0        AL   Alabama         NaN      Mobile
# 9    6  1101.0        AL   Alabama         NaN  Montgomery
# 10  10  1103.0        AL   Alabama         NaN      Morgan
# 11  11  1117.0        AL   Alabama         NaN      Shelby
# 12  12  1125.0        AL   Alabama         NaN  Tuscaloosa
# 13  14  4003.0        AZ   Arizona         NaN     Cochise
# 14  15  4005.0        AZ   Arizona         NaN    Coconino
# 15  16  4007.0        AZ   Arizona         NaN        Gila
# 16  17  4013.0        AZ   Arizona         NaN    Maricopa
# 17  18  4015.0        AZ   Arizona         NaN      Mohave
# 18  19  4017.0        AZ   Arizona         NaN      Navajo
# 19  20  4019.0        AZ   Arizona         NaN        Pima
# 20  21  4021.0        AZ   Arizona         NaN       Pinal
# 21  22  4023.0        AZ   Arizona         NaN  Santa Cruz
# 22  23  4025.0        AZ   Arizona         NaN     Yavapai
# 23  24  4027.0        AZ   Arizona         NaN        Yuma
# 24  25  5007.0        AR  Arkansas         NaN      Benton
# 25  26  5031.0        AR  Arkansas         NaN   Craighead
# 26  27  5035.0        AR  Arkansas         NaN  Crittenden
# 27  28  5045.0        AR  Arkansas         NaN    Faulkner
#
#                                                  jail  \
# 0                         Baldwin County Corr. Center
# 1                                 Calhoun County Jail
# 2                      Etowah County Detention Center
# 3                                 Houston County Jail
# 4                    Jefferson County Birmingham Jail
# 5                    W.S. Buck Jones Detention Center
# 6                   Madison County Detention Facility
# 7                                Marshall County Jail
# 8                            Mobile County Metro Jail
# 9   Mac Sim Butler Montgomery County Detention Fac...
# 10                       Morgan County Corr. Facility
# 11                                 Shelby County Jail
# 12                             Tuscaloosa County Jail
# 13                                Cochise County Jail
# 14                               Coconino County Jail
# 15                                  Gila County Jails
# 16                        Maricopa County Jail System
# 17             Mohave County Adult Detention Facility
# 18                     Navajo County Detention Center
# 19                Pima County Adult Detention Complex
# 20                                  Pinal County Jail
# 21           Santa Cruz County Adult Detention Center
# 22                 Yavapai County Camp Verde Facility
# 23                       Yuma County Detention Center
# 24                   Benton County Detention Facility
# 25                  Craighead County Detention Center
# 26                 Crittenden County Detention Center
# 27          Faulkner County Detention Center Unit 1&2
#
#                                            jail_notes  d2008  d2009  ...  \
# 0                                                 NaN    0.0    0.0  ...
# 1                                                 NaN    0.0    1.0  ...
# 2                                                 NaN    0.0    0.0  ...
# 3                                                 NaN    1.0    0.0  ...
# 4   ADP for 2008 was based on data provided by the...    NaN    NaN  ...
# 5                                                 NaN    0.0    0.0  ...
# 6                ADP for 2019 averaged from 2016-2018    0.0    0.0  ...
# 7                                                 NaN    0.0    2.0  ...
# 8                                                 NaN    0.0    1.0  ...
# 9                                                 NaN    0.0    0.0  ...
# 10                                                NaN    0.0    0.0  ...
# 11                                                NaN    3.0    0.0  ...
# 12                                                NaN    0.0    0.0  ...
# 13                                                NaN    0.0    0.0  ...
# 14                                                NaN    0.0    0.0  ...
# 15                                                NaN    0.0    0.0  ...
# 16  Cause of death information for 2018 was initia...    7.0    4.0  ...
# 17           ADP for 2018 averaged from 2016 and 2017    0.0    1.0  ...
# 18                                                NaN    0.0    0.0  ...
# 19                                                NaN    1.0    2.0  ...
# 20                                                NaN    3.0    1.0  ...
# 21                                                NaN    0.0    0.0  ...
# 22                                                NaN    0.0    1.0  ...
# 23                                                NaN    0.0    0.0  ...
# 24                                                NaN    0.0    0.0  ...
# 25                                                NaN    0.0    0.0  ...
# 26                                                NaN    1.0    0.0  ...
# 27                                                NaN    0.0    0.0  ...
#
#                                      med2010  \
# 0                                     public
# 1                                     public
# 2      Doctors' Care Family Medical Services
# 3                                     public
# 4                           Health Assurance
# 5                                     public
# 6           Advanced Correctional Healthcare
# 7                   Southern Health Partners
# 8                            Corizon Health
# 9           Quality Correctional Health Care
# 10                  Southern Health Partners
# 11                     Prison Healthcare LLC
# 12  Whatley Health Services (Tuscaloosa, AL)
# 13                                    public
# 14                                    public
# 15                                    public
# 16                                    public
# 17                           Corizon Health
# 18                                    public
# 19                                  Wellpath
# 20                                    public
# 21                                    public
# 22                    Wexford Health Sources
# 23                                  Wellpath
# 24                                    public
# 25                                transition
# 26                                    public
# 27                                    public
#
#                                      med2011  \
# 0                                     public
# 1                                     public
# 2      Doctors' Care Family Medical Services
# 3                                     public
# 4                                 transition
# 5                                     public
# 6           Advanced Correctional Healthcare
# 7                   Southern Health Partners
# 8                            Corizon Health
# 9           Quality Correctional Health Care
# 10                  Southern Health Partners
# 11                     Prison Healthcare LLC
# 12  Whatley Health Services (Tuscaloosa, AL)
# 13                                    public
# 14                                    public
# 15                                    public
# 16                                    public
# 17                           Corizon Health
# 18                                    public
# 19                                  Wellpath
# 20                                    public
# 21                                    public
# 22                    Wexford Health Sources
# 23                                  Wellpath
# 24                                    public
# 25          Advanced Correctional Healthcare
# 26                                    public
# 27                                    public
#
#                                      med2012  \
# 0                                     public
# 1                                     public
# 2      Doctors' Care Family Medical Services
# 3                                     public
# 4           Advanced Correctional Healthcare
# 5                                     public
# 6           Advanced Correctional Healthcare
# 7                   Southern Health Partners
# 8                            Corizon Health
# 9           Quality Correctional Health Care
# 10                  Southern Health Partners
# 11                     Prison Healthcare LLC
# 12  Whatley Health Services (Tuscaloosa, AL)
# 13                                    public
# 14                                    public
# 15                                    public
# 16                                    public
# 17                           Corizon Health
# 18                                    public
# 19                                  Wellpath
# 20                                    public
# 21                                    public
# 22                    Wexford Health Sources
# 23                                  Wellpath
# 24                                    public
# 25          Advanced Correctional Healthcare
# 26                                    public
# 27                                    public
#
#                                      med2013  \
# 0                                     public
# 1                                     public
# 2      Doctors' Care Family Medical Services
# 3                                     public
# 4           Advanced Correctional Healthcare
# 5                                     public
# 6           Advanced Correctional Healthcare
# 7                   Southern Health Partners
# 8                            Corizon Health
# 9           Quality Correctional Health Care
# 10                  Southern Health Partners
# 11                     Prison Healthcare LLC
# 12  Whatley Health Services (Tuscaloosa, AL)
# 13                                    public
# 14                                    public
# 15                                    public
# 16                                    public
# 17                           Corizon Health
# 18                                    public
# 19                                  Wellpath
# 20                                    public
# 21                                    public
# 22                    Wexford Health Sources
# 23                                  Wellpath
# 24                                    public
# 25          Advanced Correctional Healthcare
# 26                                    public
# 27                                    public
#
#                                      med2014  \
# 0                                     public
# 1                                     public
# 2      Doctors' Care Family Medical Services
# 3                                     public
# 4           Advanced Correctional Healthcare
# 5                                     public
# 6           Advanced Correctional Healthcare
# 7                   Southern Health Partners
# 8                             NaphCare, Inc.
# 9           Quality Correctional Health Care
# 10                  Southern Health Partners
# 11                                transition
# 12  Whatley Health Services (Tuscaloosa, AL)
# 13                                    public
# 14                                    public
# 15                                    public
# 16                                    public
# 17                                transition
# 18                                    public
# 19                                  Wellpath
# 20                                    public
# 21                                    public
# 22                    Wexford Health Sources
# 23                                  Wellpath
# 24                                transition
# 25          Advanced Correctional Healthcare
# 26                                    public
# 27                                    public
#
#                                      med2015  \
# 0                                     public
# 1                                 transition
# 2      Doctors' Care Family Medical Services
# 3                                     public
# 4           Advanced Correctional Healthcare
# 5                                     public
# 6                                 transition
# 7                                 transition
# 8                             NaphCare, Inc.
# 9           Quality Correctional Health Care
# 10                                transition
# 11          Quality Correctional Health Care
# 12  Whatley Health Services (Tuscaloosa, AL)
# 13                                    public
# 14                                    public
# 15                                    public
# 16                                    public
# 17                                  Wellpath
# 18                                    public
# 19                                  Wellpath
# 20                                    public
# 21                                    public
# 22                    Wexford Health Sources
# 23                                  Wellpath
# 24                  Southern Health Partners
# 25          Advanced Correctional Healthcare
# 26                                    public
# 27                                    public
#
#                                      med2016  \
# 0                                 transition
# 1           Quality Correctional Health Care
# 2      Doctors' Care Family Medical Services
# 3                                     public
# 4           Advanced Correctional Healthcare
# 5                                     public
# 6                   Southern Health Partners
# 7           Advanced Correctional Healthcare
# 8                             NaphCare, Inc.
# 9           Quality Correctional Health Care
# 10          Quality Correctional Health Care
# 11          Quality Correctional Health Care
# 12  Whatley Health Services (Tuscaloosa, AL)
# 13                                    public
# 14                                    public
# 15                                    public
# 16                                    public
# 17                                  Wellpath
# 18                                    public
# 19                                  Wellpath
# 20                                    public
# 21                                    public
# 22                    Wexford Health Sources
# 23                                  Wellpath
# 24                  Southern Health Partners
# 25          Advanced Correctional Healthcare
# 26                                    public
# 27                                    public
#
#                                      med2017  \
# 0           Quality Correctional Health Care
# 1                                 transition
# 2      Doctors' Care Family Medical Services
# 3                                     public
# 4           Advanced Correctional Healthcare
# 5                                     public
# 6                   Southern Health Partners
# 7           Advanced Correctional Healthcare
# 8                             NaphCare, Inc.
# 9           Quality Correctional Health Care
# 10          Quality Correctional Health Care
# 11          Quality Correctional Health Care
# 12  Whatley Health Services (Tuscaloosa, AL)
# 13                                    public
# 14                                    public
# 15                                    public
# 16                                    public
# 17                                  Wellpath
# 18                                    public
# 19                                  Wellpath
# 20                                transition
# 21                                    public
# 22                    Wexford Health Sources
# 23                                  Wellpath
# 24                  Southern Health Partners
# 25                                transition
# 26                                    public
# 27                                    public
#
#                                      med2018  \
# 0           Quality Correctional Health Care
# 1                   Southern Health Partners
# 2      Doctors' Care Family Medical Services
# 3                                     public
# 4           Advanced Correctional Healthcare
# 5                                     public
# 6                   Southern Health Partners
# 7           Advanced Correctional Healthcare
# 8                             NaphCare, Inc.
# 9           Quality Correctional Health Care
# 10          Quality Correctional Health Care
# 11          Quality Correctional Health Care
# 12  Whatley Health Services (Tuscaloosa, AL)
# 13                                    public
# 14                                    public
# 15                                    public
# 16                                    public
# 17                                  Wellpath
# 18                                    public
# 19                                transition
# 20                    Wexford Health Sources
# 21                                    public
# 22                    Wexford Health Sources
# 23                                  Wellpath
# 24                                transition
# 25                           Turn-Key Health
# 26                                    public
# 27                                    public
#
#                                      med2019
# 0           Quality Correctional Health Care
# 1                   Southern Health Partners
# 2                                    Unknown
# 3                                     public
# 4           Advanced Correctional Healthcare
# 5                                     public
# 6                   Southern Health Partners
# 7                                 transition
# 8                             NaphCare, Inc.
# 9           Quality Correctional Health Care
# 10          Quality Correctional Health Care
# 11                                transition
# 12  Whatley Health Services (Tuscaloosa, AL)
# 13                                   Unknown
# 14                                    public
# 15                                   Unknown
# 16                                   Unknown
# 17                                  Wellpath
# 18                                    public
# 19                                   Unknown
# 20                    Wexford Health Sources
# 21                                    public
# 22                    Wexford Health Sources
# 23                                  Wellpath
# 24                           Turn-Key Health
# 25                           Turn-Key Health
# 26                                    public
# 27                                    public
#
# [28 rows x 116 columns]
