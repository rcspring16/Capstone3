# %%
import pandas as pd
import numpy as np
import re

# %%
jails_df = pd.read_csv("all_jails.csv")

# %%
jails_df
# Out:
#       id     fips statecode    state state_notes      county  \
# 0      1   1003.0        AL  Alabama         NaN     Baldwin
# 1      2   1015.0        AL  Alabama         NaN     Calhoun
# 2      3   1055.0        AL  Alabama         NaN      Etowah
# 3      4   1069.0        AL  Alabama         NaN     Houston
# 4      5   1073.0        AL  Alabama         NaN   Jefferson
# ..   ...      ...       ...      ...         ...         ...
# 518  498  56021.0        WY  Wyoming         NaN     Laramie
# 519  499  56025.0        WY  Wyoming         NaN     Natrona
# 520  500  56031.0        WY  Wyoming         NaN      Platte
# 521  501  56033.0        WY  Wyoming         NaN    Sheridan
# 522  502  56037.0        WY  Wyoming         NaN  Sweetwater
#
#                                    jail  \
# 0           Baldwin County Corr. Center
# 1                   Calhoun County Jail
# 2        Etowah County Detention Center
# 3                   Houston County Jail
# 4      Jefferson County Birmingham Jail
# ..                                  ...
# 518   Laramie County Detention Facility
# 519     Natrona County Detention Center
# 520      Platte County Detention Center
# 521    Sheridan County Detention Center
# 522  Sweetwater County Detention Center
#
#                                             jail_notes  d2008  d2009  ...  \
# 0                                                  NaN    0.0    0.0  ...
# 1                                                  NaN    0.0    1.0  ...
# 2                                                  NaN    0.0    0.0  ...
# 3                                                  NaN    1.0    0.0  ...
# 4    ADP for 2008 was based on data provided by the...    NaN    NaN  ...
# ..                                                 ...    ...    ...  ...
# 518                                                NaN    0.0    0.0  ...
# 519                                                NaN    0.0    1.0  ...
# 520                                                NaN    0.0    0.0  ...
# 521                                                NaN    0.0    0.0  ...
# 522                                                NaN    0.0    0.0  ...
#
#                                    med2010  \
# 0                                   public
# 1                                   public
# 2    Doctors' Care Family Medical Services
# 3                                   public
# 4                         Health Assurance
# ..                                     ...
# 518                               Wellpath
# 519                                 public
# 520                                 public
# 521                               Wellpath
# 522                                 public
#
#                                                med2011  \
# 0                                               public
# 1                                               public
# 2                Doctors' Care Family Medical Services
# 3                                               public
# 4    Health Assurance/Advanced Correctional Healthcare
# ..                                                 ...
# 518                                           Wellpath
# 519                                             public
# 520                                             public
# 521                                           Wellpath
# 522                                             public
#
#                                    med2012  \
# 0                                   public
# 1                                   public
# 2    Doctors' Care Family Medical Services
# 3                                   public
# 4         Advanced Correctional Healthcare
# ..                                     ...
# 518                               Wellpath
# 519                                 public
# 520                                 public
# 521                               Wellpath
# 522                                 public
#
#                                    med2013  \
# 0                                   public
# 1                                   public
# 2    Doctors' Care Family Medical Services
# 3                                   public
# 4         Advanced Correctional Healthcare
# ..                                     ...
# 518                               Wellpath
# 519                                 public
# 520                                 public
# 521                               Wellpath
# 522                                 public
#
#                                    med2014  \
# 0                                   public
# 1                                   public
# 2    Doctors' Care Family Medical Services
# 3                                   public
# 4         Advanced Correctional Healthcare
# ..                                     ...
# 518                               Wellpath
# 519                                 public
# 520                                 public
# 521                               Wellpath
# 522                                 public
#
#                                      med2015  \
# 0                                     public
# 1    public/Quality Correctional Health Care
# 2      Doctors' Care Family Medical Services
# 3                                     public
# 4           Advanced Correctional Healthcare
# ..                                       ...
# 518                                 Wellpath
# 519                                   public
# 520                                   public
# 521                                 Wellpath
# 522                                   public
#
#                                      med2016  \
# 0    public/Quality Correctional Health Care
# 1           Quality Correctional Health Care
# 2      Doctors' Care Family Medical Services
# 3                                     public
# 4           Advanced Correctional Healthcare
# ..                                       ...
# 518                                 Wellpath
# 519                                   public
# 520                                   public
# 521                                 Wellpath
# 522                                   public
#
#                                                med2017  \
# 0                     Quality Correctional Health Care
# 1    Quality Correctional Health Care/Southern Heal...
# 2                Doctors' Care Family Medical Services
# 3                                               public
# 4                     Advanced Correctional Healthcare
# ..                                                 ...
# 518                                           Wellpath
# 519                                             public
# 520                                             public
# 521                                           Wellpath
# 522                                             public
#
#                                    med2018                           med2019
# 0         Quality Correctional Health Care  Quality Correctional Health Care
# 1                 Southern Health Partners          Southern Health Partners
# 2    Doctors' Care Family Medical Services                               NaN
# 3                                   public                            public
# 4         Advanced Correctional Healthcare  Advanced Correctional Healthcare
# ..                                     ...                               ...
# 518                               Wellpath                          Wellpath
# 519                                 public                               NaN
# 520                                 public                            public
# 521                               Wellpath                          Wellpath
# 522                                 public                            public
#
# [523 rows x 116 columns]

# %%
df= jails_df.dropna(subset=['med2008', 'med2009', 'med2010', 'med2011', 'med2012', 'med2013', 'med2014', 'med2015', 'med2016', 'med2017', 'med2018', 'med2019'])

# %%
df.head(35)
# Out:
#      id    fips statecode       state  \
# 0     1  1003.0        AL     Alabama
# 1     2  1015.0        AL     Alabama
# 3     4  1069.0        AL     Alabama
# 4     5  1073.0        AL     Alabama
# 5    13  1081.0        AL     Alabama
# 6     7  1089.0        AL     Alabama
# 7     8  1095.0        AL     Alabama
# 8     9  1097.0        AL     Alabama
# 9     6  1101.0        AL     Alabama
# 10   10  1103.0        AL     Alabama
# 11   11  1117.0        AL     Alabama
# 12   12  1125.0        AL     Alabama
# 14   15  4005.0        AZ     Arizona
# 17   18  4015.0        AZ     Arizona
# 18   19  4017.0        AZ     Arizona
# 20   21  4021.0        AZ     Arizona
# 21   22  4023.0        AZ     Arizona
# 22   23  4025.0        AZ     Arizona
# 23   24  4027.0        AZ     Arizona
# 24   25  5007.0        AR    Arkansas
# 25   26  5031.0        AR    Arkansas
# 26   27  5035.0        AR    Arkansas
# 27   28  5045.0        AR    Arkansas
# 28   32  5069.0        AR    Arkansas
# 29   29  5091.0        AR    Arkansas
# 30   30  5119.0        AR    Arkansas
# 31   31  5131.0        AR    Arkansas
# 32   33  5143.0        AR    Arkansas
# 34   36  6001.0        CA  California
# 35   35  6001.0        CA  California
# 36  504  6013.0        CA  California
# 37   37  6013.0        CA  California
# 38   39  6019.0        CA  California
# 39  511  6029.0        CA  California
# 41  512  6029.0        CA  California
#
#                                           state_notes        county  \
# 0                                                 NaN       Baldwin
# 1                                                 NaN       Calhoun
# 3                                                 NaN       Houston
# 4                                                 NaN     Jefferson
# 5                                                 NaN           Lee
# 6                                                 NaN       Madison
# 7                                                 NaN      Marshall
# 8                                                 NaN        Mobile
# 9                                                 NaN    Montgomery
# 10                                                NaN        Morgan
# 11                                                NaN        Shelby
# 12                                                NaN    Tuscaloosa
# 14                                                NaN      Coconino
# 17                                                NaN        Mohave
# 18                                                NaN        Navajo
# 20                                                NaN         Pinal
# 21                                                NaN    Santa Cruz
# 22                                                NaN       Yavapai
# 23                                                NaN          Yuma
# 24                                                NaN        Benton
# 25                                                NaN     Craighead
# 26                                                NaN    Crittenden
# 27                                                NaN      Faulkner
# 28                                                NaN     Jefferson
# 29                                                NaN        Miller
# 30                                                NaN       Pulaski
# 31                                                NaN     Sebastian
# 32                                                NaN    Washington
# 34  In 2011, a California law known as �realignmen...       Alameda
# 35  In 2011, a California law known as �realignmen...       Alameda
# 36  In 2011, a California law known as �realignmen...  Contra Costa
# 37  In 2011, a California law known as �realignmen...  Contra Costa
# 38  In 2011, a California law known as �realignmen...        Fresno
# 39  In 2011, a California law known as �realignmen...          Kern
# 41  In 2011, a California law known as �realignmen...          Kern
#
#                                                  jail  \
# 0                         Baldwin County Corr. Center
# 1                                 Calhoun County Jail
# 3                                 Houston County Jail
# 4                    Jefferson County Birmingham Jail
# 5                    W.S. Buck Jones Detention Center
# 6                   Madison County Detention Facility
# 7                                Marshall County Jail
# 8                            Mobile County Metro Jail
# 9   Mac Sim Butler Montgomery County Detention Fac...
# 10                       Morgan County Corr. Facility
# 11                                 Shelby County Jail
# 12                             Tuscaloosa County Jail
# 14                               Coconino County Jail
# 17             Mohave County Adult Detention Facility
# 18                     Navajo County Detention Center
# 20                                  Pinal County Jail
# 21           Santa Cruz County Adult Detention Center
# 22                 Yavapai County Camp Verde Facility
# 23                       Yuma County Detention Center
# 24                   Benton County Detention Facility
# 25                  Craighead County Detention Center
# 26                 Crittenden County Detention Center
# 27          Faulkner County Detention Center Unit 1&2
# 28  W.C. Brassell Adult Detention Center (Jefferso...
# 29                                 Miller County Jail
# 30         Pulaski County Regional Detention Facility
# 31            Sebastian County Adult Detention Center
# 32                 Washington County Detention Center
# 34    Alameda County Glenn E. Dyer Detention Facility
# 35                     Alameda County Santa Rita Jail
# 36           Contra Costa Martinez Detention Facility
# 37        Contra Costa West County Detention Facility
# 38  Fresno County Jail (inc. both North and South ...
# 39             Kern County Central Receiving Facility
# 41        Kern County Lerdo Max-Med Security Facility
#
#                                            jail_notes  d2008  d2009  ...  \
# 0                                                 NaN    0.0    0.0  ...
# 1                                                 NaN    0.0    1.0  ...
# 3                                                 NaN    1.0    0.0  ...
# 4   ADP for 2008 was based on data provided by the...    NaN    NaN  ...
# 5                                                 NaN    0.0    0.0  ...
# 6                ADP for 2019 averaged from 2016-2018    0.0    0.0  ...
# 7                                                 NaN    0.0    2.0  ...
# 8                                                 NaN    0.0    1.0  ...
# 9                                                 NaN    0.0    0.0  ...
# 10                                                NaN    0.0    0.0  ...
# 11                                                NaN    3.0    0.0  ...
# 12                                                NaN    0.0    0.0  ...
# 14                                                NaN    0.0    0.0  ...
# 17           ADP for 2018 averaged from 2016 and 2017    0.0    1.0  ...
# 18                                                NaN    0.0    0.0  ...
# 20                                                NaN    3.0    1.0  ...
# 21                                                NaN    0.0    0.0  ...
# 22                                                NaN    0.0    1.0  ...
# 23                                                NaN    0.0    0.0  ...
# 24                                                NaN    0.0    0.0  ...
# 25                                                NaN    0.0    0.0  ...
# 26                                                NaN    1.0    0.0  ...
# 27                                                NaN    0.0    0.0  ...
# 28                                                NaN    0.0    0.0  ...
# 29                                                NaN    0.0    0.0  ...
# 30                                                NaN    2.0    1.0  ...
# 31                                                NaN    0.0    2.0  ...
# 32                                                NaN    0.0    0.0  ...
# 34  The Glenn E. Dyer Detention Facility closed in...    0.0    0.0  ...
# 35                                                NaN   13.0    3.0  ...
# 36                                                NaN    1.0    3.0  ...
# 37                                                NaN    1.0    2.0  ...
# 38                                                NaN    3.0    6.0  ...
# 39  ADP for Kern County jails from 2009-2010 was d...    1.0    2.0  ...
# 41  Lerdo Justice Facility opened in 2018 and inma...    0.0    0.0  ...
#
#                                      med2010  \
# 0                                     public
# 1                                     public
# 3                                     public
# 4                           Health Assurance
# 5                                     public
# 6           Advanced Correctional Healthcare
# 7                   Southern Health Partners
# 8                            Corizon Health
# 9           Quality Correctional Health Care
# 10                  Southern Health Partners
# 11                     Prison Healthcare LLC
# 12  Whatley Health Services (Tuscaloosa, AL)
# 14                                    public
# 17                           Corizon Health
# 18                                    public
# 20                                    public
# 21                                    public
# 22                    Wexford Health Sources
# 23                                  Wellpath
# 24                                    public
# 25   public/Advanced Correctional Healthcare
# 26                                    public
# 27                                    public
# 28                                    public
# 29                                    public
# 30                                    public
# 31                                    public
# 32                                    public
# 34                           Corizon Health
# 35                           Corizon Health
# 36                                    public
# 37                                    public
# 38                                    public
# 39                                    public
# 41                                    public
#
#                                               med2011  \
# 0                                              public
# 1                                              public
# 3                                              public
# 4   Health Assurance/Advanced Correctional Healthcare
# 5                                              public
# 6                    Advanced Correctional Healthcare
# 7                            Southern Health Partners
# 8                                     Corizon Health
# 9                    Quality Correctional Health Care
# 10                           Southern Health Partners
# 11                              Prison Healthcare LLC
# 12           Whatley Health Services (Tuscaloosa, AL)
# 14                                             public
# 17                                    Corizon Health
# 18                                             public
# 20                                             public
# 21                                             public
# 22                             Wexford Health Sources
# 23                                           Wellpath
# 24                                             public
# 25                   Advanced Correctional Healthcare
# 26                                             public
# 27                                             public
# 28                                             public
# 29                                             public
# 30                                             public
# 31                                             public
# 32                                             public
# 34                                    Corizon Health
# 35                                    Corizon Health
# 36                                             public
# 37                                             public
# 38                                             public
# 39                                             public
# 41                                             public
#
#                                      med2012  \
# 0                                     public
# 1                                     public
# 3                                     public
# 4           Advanced Correctional Healthcare
# 5                                     public
# 6           Advanced Correctional Healthcare
# 7                   Southern Health Partners
# 8                            Corizon Health
# 9           Quality Correctional Health Care
# 10                  Southern Health Partners
# 11                     Prison Healthcare LLC
# 12  Whatley Health Services (Tuscaloosa, AL)
# 14                                    public
# 17                           Corizon Health
# 18                                    public
# 20                                    public
# 21                                    public
# 22                    Wexford Health Sources
# 23                                  Wellpath
# 24                                    public
# 25          Advanced Correctional Healthcare
# 26                                    public
# 27                                    public
# 28                                    public
# 29                                    public
# 30                                    public
# 31                                    public
# 32                                    public
# 34                           Corizon Health
# 35                           Corizon Health
# 36                                    public
# 37                                    public
# 38                                    public
# 39                                    public
# 41                                    public
#
#                                      med2013  \
# 0                                     public
# 1                                     public
# 3                                     public
# 4           Advanced Correctional Healthcare
# 5                                     public
# 6           Advanced Correctional Healthcare
# 7                   Southern Health Partners
# 8                            Corizon Health
# 9           Quality Correctional Health Care
# 10                  Southern Health Partners
# 11                     Prison Healthcare LLC
# 12  Whatley Health Services (Tuscaloosa, AL)
# 14                                    public
# 17                           Corizon Health
# 18                                    public
# 20                                    public
# 21                                    public
# 22                    Wexford Health Sources
# 23                                  Wellpath
# 24                                    public
# 25          Advanced Correctional Healthcare
# 26                                    public
# 27                                    public
# 28                                    public
# 29                                    public
# 30                                    public
# 31                                    public
# 32                                    public
# 34                           Corizon Health
# 35                           Corizon Health
# 36                                    public
# 37                                    public
# 38                                    public
# 39                                    public
# 41                                    public
#
#                                               med2014  \
# 0                                              public
# 1                                              public
# 3                                              public
# 4                    Advanced Correctional Healthcare
# 5                                              public
# 6                    Advanced Correctional Healthcare
# 7                            Southern Health Partners
# 8                                      NaphCare, Inc.
# 9                    Quality Correctional Health Care
# 10                           Southern Health Partners
# 11  Prison Healthcare LLC/Quality Correctional Hea...
# 12           Whatley Health Services (Tuscaloosa, AL)
# 14                                             public
# 17                            Corizon Health/Wellpath
# 18                                             public
# 20                                             public
# 21                                             public
# 22                             Wexford Health Sources
# 23                                           Wellpath
# 24                    public/Southern Health Partners
# 25                   Advanced Correctional Healthcare
# 26                                             public
# 27                                             public
# 28                                             public
# 29                                             public
# 30                                             public
# 31                                             public
# 32                                             public
# 34                                    Corizon Health
# 35                                    Corizon Health
# 36                                             public
# 37                                             public
# 38                              public/Corizon Health
# 39                                             public
# 41                                             public
#
#                                               med2015  \
# 0                                              public
# 1             public/Quality Correctional Health Care
# 3                                              public
# 4                    Advanced Correctional Healthcare
# 5                                              public
# 6   Advanced Correctional Healthcare/Southern Heal...
# 7   Southern Health Partners/Advanced Correctional...
# 8                                      NaphCare, Inc.
# 9                    Quality Correctional Health Care
# 10  Southern Health Partners/Quality Correctional ...
# 11                   Quality Correctional Health Care
# 12           Whatley Health Services (Tuscaloosa, AL)
# 14                                             public
# 17                                           Wellpath
# 18                                             public
# 20                                             public
# 21                                             public
# 22                             Wexford Health Sources
# 23                                           Wellpath
# 24                           Southern Health Partners
# 25                   Advanced Correctional Healthcare
# 26                                             public
# 27                                             public
# 28                                             public
# 29                           Southern Health Partners
# 30                             public/Turn-Key Health
# 31                                             public
# 32                           Southern Health Partners
# 34                                    Corizon Health
# 35                                    Corizon Health
# 36                                             public
# 37                                             public
# 38                                    Corizon Health
# 39                                             public
# 41                                             public
#
#                                      med2016  \
# 0    public/Quality Correctional Health Care
# 1           Quality Correctional Health Care
# 3                                     public
# 4           Advanced Correctional Healthcare
# 5                                     public
# 6                   Southern Health Partners
# 7           Advanced Correctional Healthcare
# 8                             NaphCare, Inc.
# 9           Quality Correctional Health Care
# 10          Quality Correctional Health Care
# 11          Quality Correctional Health Care
# 12  Whatley Health Services (Tuscaloosa, AL)
# 14                                    public
# 17                                  Wellpath
# 18                                    public
# 20                                    public
# 21                                    public
# 22                    Wexford Health Sources
# 23                                  Wellpath
# 24                  Southern Health Partners
# 25          Advanced Correctional Healthcare
# 26                                    public
# 27                                    public
# 28                                    public
# 29                  Southern Health Partners
# 30                           Turn-Key Health
# 31                                    public
# 32                Karas Correctional Health
# 34                   Corizon Health/Wellpath
# 35                   Corizon Health/Wellpath
# 36                                    public
# 37                                    public
# 38                           Corizon Health
# 39                                    public
# 41                                    public
#
#                                               med2017  \
# 0                    Quality Correctional Health Care
# 1   Quality Correctional Health Care/Southern Heal...
# 3                                              public
# 4                    Advanced Correctional Healthcare
# 5                                              public
# 6                            Southern Health Partners
# 7                    Advanced Correctional Healthcare
# 8                                      NaphCare, Inc.
# 9                    Quality Correctional Health Care
# 10                   Quality Correctional Health Care
# 11                   Quality Correctional Health Care
# 12           Whatley Health Services (Tuscaloosa, AL)
# 14                                             public
# 17                                           Wellpath
# 18                                             public
# 20                      public/Wexford Health Sources
# 21                                             public
# 22                             Wexford Health Sources
# 23                                           Wellpath
# 24                           Southern Health Partners
# 25   Advanced Correctional Healthcare/Turn-Key Health
# 26                                             public
# 27                                             public
# 28                                             public
# 29                           Southern Health Partners
# 30                                    Turn-Key Health
# 31                                             public
# 32                         Karas Correctional Health
# 34                                           Wellpath
# 35                                           Wellpath
# 36                                             public
# 37                                             public
# 38                                    Corizon Health
# 39                                             public
# 41                                             public
#
#                                      med2018  \
# 0           Quality Correctional Health Care
# 1                   Southern Health Partners
# 3                                     public
# 4           Advanced Correctional Healthcare
# 5                                     public
# 6                   Southern Health Partners
# 7           Advanced Correctional Healthcare
# 8                             NaphCare, Inc.
# 9           Quality Correctional Health Care
# 10          Quality Correctional Health Care
# 11          Quality Correctional Health Care
# 12  Whatley Health Services (Tuscaloosa, AL)
# 14                                    public
# 17                                  Wellpath
# 18                                    public
# 20                    Wexford Health Sources
# 21                                    public
# 22                    Wexford Health Sources
# 23                                  Wellpath
# 24  Southern Health Partners/Turn-Key Health
# 25                           Turn-Key Health
# 26                                    public
# 27                                    public
# 28                                    public
# 29                  Southern Health Partners
# 30                           Turn-Key Health
# 31                                    public
# 32                Karas Correctional Health
# 34                                  Wellpath
# 35                                  Wellpath
# 36                                    public
# 37                                    public
# 38                   Corizon Health/Wellpath
# 39                                    public
# 41                                    public
#
#                                               med2019
# 0                    Quality Correctional Health Care
# 1                            Southern Health Partners
# 3                                              public
# 4                    Advanced Correctional Healthcare
# 5                                              public
# 6                            Southern Health Partners
# 7   Advanced Correctional Healthcare/Southern Heal...
# 8                                      NaphCare, Inc.
# 9                    Quality Correctional Health Care
# 10                   Quality Correctional Health Care
# 11  Quality Correctional Health Care/Southern Heal...
# 12           Whatley Health Services (Tuscaloosa, AL)
# 14                                             public
# 17                                           Wellpath
# 18                                             public
# 20                             Wexford Health Sources
# 21                                             public
# 22                             Wexford Health Sources
# 23                                           Wellpath
# 24                                    Turn-Key Health
# 25                                    Turn-Key Health
# 26                                             public
# 27                                             public
# 28                                             public
# 29                           Southern Health Partners
# 30                                    Turn-Key Health
# 31                             public/Turn-Key Health
# 32                         Karas Correctional Health
# 34                                           Wellpath
# 35                                           Wellpath
# 36                                             public
# 37                                             public
# 38                                           Wellpath
# 39                                             public
# 41                                             public
#
# [35 rows x 116 columns]

# %%
df.loc[df['med2008'].str.contains('/'), 'med2008'] = 'transition'
df.loc[df['med2009'].str.contains('/'), 'med2009'] = 'transition'
df.loc[df['med2010'].str.contains('/'), 'med2010'] = 'transition'
df.loc[df['med2011'].str.contains('/'), 'med2011'] = 'transition'
df.loc[df['med2012'].str.contains('/'), 'med2012'] = 'transition'
df.loc[df['med2013'].str.contains('/'), 'med2013'] = 'transition'
df.loc[df['med2014'].str.contains('/'), 'med2014'] = 'transition'
df.loc[df['med2015'].str.contains('/'), 'med2015'] = 'transition'
df.loc[df['med2016'].str.contains('/'), 'med2016'] = 'transition'
df.loc[df['med2017'].str.contains('/'), 'med2017'] = 'transition'
df.loc[df['med2018'].str.contains('/'), 'med2018'] = 'transition'
df.loc[df['med2019'].str.contains('/'), 'med2019'] = 'transition'
# Out:
# /Users/rachelspring/.pyenv/versions/3.9.1/lib/python3.9/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.head(30)
# Out:
#     id    fips statecode       state  \
# 0    1  1003.0        AL     Alabama
# 1    2  1015.0        AL     Alabama
# 3    4  1069.0        AL     Alabama
# 4    5  1073.0        AL     Alabama
# 5   13  1081.0        AL     Alabama
# 6    7  1089.0        AL     Alabama
# 7    8  1095.0        AL     Alabama
# 8    9  1097.0        AL     Alabama
# 9    6  1101.0        AL     Alabama
# 10  10  1103.0        AL     Alabama
# 11  11  1117.0        AL     Alabama
# 12  12  1125.0        AL     Alabama
# 14  15  4005.0        AZ     Arizona
# 17  18  4015.0        AZ     Arizona
# 18  19  4017.0        AZ     Arizona
# 20  21  4021.0        AZ     Arizona
# 21  22  4023.0        AZ     Arizona
# 22  23  4025.0        AZ     Arizona
# 23  24  4027.0        AZ     Arizona
# 24  25  5007.0        AR    Arkansas
# 25  26  5031.0        AR    Arkansas
# 26  27  5035.0        AR    Arkansas
# 27  28  5045.0        AR    Arkansas
# 28  32  5069.0        AR    Arkansas
# 29  29  5091.0        AR    Arkansas
# 30  30  5119.0        AR    Arkansas
# 31  31  5131.0        AR    Arkansas
# 32  33  5143.0        AR    Arkansas
# 34  36  6001.0        CA  California
# 35  35  6001.0        CA  California
#
#                                           state_notes      county  \
# 0                                                 NaN     Baldwin
# 1                                                 NaN     Calhoun
# 3                                                 NaN     Houston
# 4                                                 NaN   Jefferson
# 5                                                 NaN         Lee
# 6                                                 NaN     Madison
# 7                                                 NaN    Marshall
# 8                                                 NaN      Mobile
# 9                                                 NaN  Montgomery
# 10                                                NaN      Morgan
# 11                                                NaN      Shelby
# 12                                                NaN  Tuscaloosa
# 14                                                NaN    Coconino
# 17                                                NaN      Mohave
# 18                                                NaN      Navajo
# 20                                                NaN       Pinal
# 21                                                NaN  Santa Cruz
# 22                                                NaN     Yavapai
# 23                                                NaN        Yuma
# 24                                                NaN      Benton
# 25                                                NaN   Craighead
# 26                                                NaN  Crittenden
# 27                                                NaN    Faulkner
# 28                                                NaN   Jefferson
# 29                                                NaN      Miller
# 30                                                NaN     Pulaski
# 31                                                NaN   Sebastian
# 32                                                NaN  Washington
# 34  In 2011, a California law known as �realignmen...     Alameda
# 35  In 2011, a California law known as �realignmen...     Alameda
#
#                                                  jail  \
# 0                         Baldwin County Corr. Center
# 1                                 Calhoun County Jail
# 3                                 Houston County Jail
# 4                    Jefferson County Birmingham Jail
# 5                    W.S. Buck Jones Detention Center
# 6                   Madison County Detention Facility
# 7                                Marshall County Jail
# 8                            Mobile County Metro Jail
# 9   Mac Sim Butler Montgomery County Detention Fac...
# 10                       Morgan County Corr. Facility
# 11                                 Shelby County Jail
# 12                             Tuscaloosa County Jail
# 14                               Coconino County Jail
# 17             Mohave County Adult Detention Facility
# 18                     Navajo County Detention Center
# 20                                  Pinal County Jail
# 21           Santa Cruz County Adult Detention Center
# 22                 Yavapai County Camp Verde Facility
# 23                       Yuma County Detention Center
# 24                   Benton County Detention Facility
# 25                  Craighead County Detention Center
# 26                 Crittenden County Detention Center
# 27          Faulkner County Detention Center Unit 1&2
# 28  W.C. Brassell Adult Detention Center (Jefferso...
# 29                                 Miller County Jail
# 30         Pulaski County Regional Detention Facility
# 31            Sebastian County Adult Detention Center
# 32                 Washington County Detention Center
# 34    Alameda County Glenn E. Dyer Detention Facility
# 35                     Alameda County Santa Rita Jail
#
#                                            jail_notes  d2008  d2009  ...  \
# 0                                                 NaN    0.0    0.0  ...
# 1                                                 NaN    0.0    1.0  ...
# 3                                                 NaN    1.0    0.0  ...
# 4   ADP for 2008 was based on data provided by the...    NaN    NaN  ...
# 5                                                 NaN    0.0    0.0  ...
# 6                ADP for 2019 averaged from 2016-2018    0.0    0.0  ...
# 7                                                 NaN    0.0    2.0  ...
# 8                                                 NaN    0.0    1.0  ...
# 9                                                 NaN    0.0    0.0  ...
# 10                                                NaN    0.0    0.0  ...
# 11                                                NaN    3.0    0.0  ...
# 12                                                NaN    0.0    0.0  ...
# 14                                                NaN    0.0    0.0  ...
# 17           ADP for 2018 averaged from 2016 and 2017    0.0    1.0  ...
# 18                                                NaN    0.0    0.0  ...
# 20                                                NaN    3.0    1.0  ...
# 21                                                NaN    0.0    0.0  ...
# 22                                                NaN    0.0    1.0  ...
# 23                                                NaN    0.0    0.0  ...
# 24                                                NaN    0.0    0.0  ...
# 25                                                NaN    0.0    0.0  ...
# 26                                                NaN    1.0    0.0  ...
# 27                                                NaN    0.0    0.0  ...
# 28                                                NaN    0.0    0.0  ...
# 29                                                NaN    0.0    0.0  ...
# 30                                                NaN    2.0    1.0  ...
# 31                                                NaN    0.0    2.0  ...
# 32                                                NaN    0.0    0.0  ...
# 34  The Glenn E. Dyer Detention Facility closed in...    0.0    0.0  ...
# 35                                                NaN   13.0    3.0  ...
#
#                                      med2010  \
# 0                                     public
# 1                                     public
# 3                                     public
# 4                           Health Assurance
# 5                                     public
# 6           Advanced Correctional Healthcare
# 7                   Southern Health Partners
# 8                            Corizon Health
# 9           Quality Correctional Health Care
# 10                  Southern Health Partners
# 11                     Prison Healthcare LLC
# 12  Whatley Health Services (Tuscaloosa, AL)
# 14                                    public
# 17                           Corizon Health
# 18                                    public
# 20                                    public
# 21                                    public
# 22                    Wexford Health Sources
# 23                                  Wellpath
# 24                                    public
# 25                                transition
# 26                                    public
# 27                                    public
# 28                                    public
# 29                                    public
# 30                                    public
# 31                                    public
# 32                                    public
# 34                           Corizon Health
# 35                           Corizon Health
#
#                                      med2011  \
# 0                                     public
# 1                                     public
# 3                                     public
# 4                                 transition
# 5                                     public
# 6           Advanced Correctional Healthcare
# 7                   Southern Health Partners
# 8                            Corizon Health
# 9           Quality Correctional Health Care
# 10                  Southern Health Partners
# 11                     Prison Healthcare LLC
# 12  Whatley Health Services (Tuscaloosa, AL)
# 14                                    public
# 17                           Corizon Health
# 18                                    public
# 20                                    public
# 21                                    public
# 22                    Wexford Health Sources
# 23                                  Wellpath
# 24                                    public
# 25          Advanced Correctional Healthcare
# 26                                    public
# 27                                    public
# 28                                    public
# 29                                    public
# 30                                    public
# 31                                    public
# 32                                    public
# 34                           Corizon Health
# 35                           Corizon Health
#
#                                      med2012  \
# 0                                     public
# 1                                     public
# 3                                     public
# 4           Advanced Correctional Healthcare
# 5                                     public
# 6           Advanced Correctional Healthcare
# 7                   Southern Health Partners
# 8                            Corizon Health
# 9           Quality Correctional Health Care
# 10                  Southern Health Partners
# 11                     Prison Healthcare LLC
# 12  Whatley Health Services (Tuscaloosa, AL)
# 14                                    public
# 17                           Corizon Health
# 18                                    public
# 20                                    public
# 21                                    public
# 22                    Wexford Health Sources
# 23                                  Wellpath
# 24                                    public
# 25          Advanced Correctional Healthcare
# 26                                    public
# 27                                    public
# 28                                    public
# 29                                    public
# 30                                    public
# 31                                    public
# 32                                    public
# 34                           Corizon Health
# 35                           Corizon Health
#
#                                      med2013  \
# 0                                     public
# 1                                     public
# 3                                     public
# 4           Advanced Correctional Healthcare
# 5                                     public
# 6           Advanced Correctional Healthcare
# 7                   Southern Health Partners
# 8                            Corizon Health
# 9           Quality Correctional Health Care
# 10                  Southern Health Partners
# 11                     Prison Healthcare LLC
# 12  Whatley Health Services (Tuscaloosa, AL)
# 14                                    public
# 17                           Corizon Health
# 18                                    public
# 20                                    public
# 21                                    public
# 22                    Wexford Health Sources
# 23                                  Wellpath
# 24                                    public
# 25          Advanced Correctional Healthcare
# 26                                    public
# 27                                    public
# 28                                    public
# 29                                    public
# 30                                    public
# 31                                    public
# 32                                    public
# 34                           Corizon Health
# 35                           Corizon Health
#
#                                      med2014  \
# 0                                     public
# 1                                     public
# 3                                     public
# 4           Advanced Correctional Healthcare
# 5                                     public
# 6           Advanced Correctional Healthcare
# 7                   Southern Health Partners
# 8                             NaphCare, Inc.
# 9           Quality Correctional Health Care
# 10                  Southern Health Partners
# 11                                transition
# 12  Whatley Health Services (Tuscaloosa, AL)
# 14                                    public
# 17                                transition
# 18                                    public
# 20                                    public
# 21                                    public
# 22                    Wexford Health Sources
# 23                                  Wellpath
# 24                                transition
# 25          Advanced Correctional Healthcare
# 26                                    public
# 27                                    public
# 28                                    public
# 29                                    public
# 30                                    public
# 31                                    public
# 32                                    public
# 34                           Corizon Health
# 35                           Corizon Health
#
#                                      med2015  \
# 0                                     public
# 1                                 transition
# 3                                     public
# 4           Advanced Correctional Healthcare
# 5                                     public
# 6                                 transition
# 7                                 transition
# 8                             NaphCare, Inc.
# 9           Quality Correctional Health Care
# 10                                transition
# 11          Quality Correctional Health Care
# 12  Whatley Health Services (Tuscaloosa, AL)
# 14                                    public
# 17                                  Wellpath
# 18                                    public
# 20                                    public
# 21                                    public
# 22                    Wexford Health Sources
# 23                                  Wellpath
# 24                  Southern Health Partners
# 25          Advanced Correctional Healthcare
# 26                                    public
# 27                                    public
# 28                                    public
# 29                  Southern Health Partners
# 30                                transition
# 31                                    public
# 32                  Southern Health Partners
# 34                           Corizon Health
# 35                           Corizon Health
#
#                                      med2016  \
# 0                                 transition
# 1           Quality Correctional Health Care
# 3                                     public
# 4           Advanced Correctional Healthcare
# 5                                     public
# 6                   Southern Health Partners
# 7           Advanced Correctional Healthcare
# 8                             NaphCare, Inc.
# 9           Quality Correctional Health Care
# 10          Quality Correctional Health Care
# 11          Quality Correctional Health Care
# 12  Whatley Health Services (Tuscaloosa, AL)
# 14                                    public
# 17                                  Wellpath
# 18                                    public
# 20                                    public
# 21                                    public
# 22                    Wexford Health Sources
# 23                                  Wellpath
# 24                  Southern Health Partners
# 25          Advanced Correctional Healthcare
# 26                                    public
# 27                                    public
# 28                                    public
# 29                  Southern Health Partners
# 30                           Turn-Key Health
# 31                                    public
# 32                Karas Correctional Health
# 34                                transition
# 35                                transition
#
#                                      med2017  \
# 0           Quality Correctional Health Care
# 1                                 transition
# 3                                     public
# 4           Advanced Correctional Healthcare
# 5                                     public
# 6                   Southern Health Partners
# 7           Advanced Correctional Healthcare
# 8                             NaphCare, Inc.
# 9           Quality Correctional Health Care
# 10          Quality Correctional Health Care
# 11          Quality Correctional Health Care
# 12  Whatley Health Services (Tuscaloosa, AL)
# 14                                    public
# 17                                  Wellpath
# 18                                    public
# 20                                transition
# 21                                    public
# 22                    Wexford Health Sources
# 23                                  Wellpath
# 24                  Southern Health Partners
# 25                                transition
# 26                                    public
# 27                                    public
# 28                                    public
# 29                  Southern Health Partners
# 30                           Turn-Key Health
# 31                                    public
# 32                Karas Correctional Health
# 34                                  Wellpath
# 35                                  Wellpath
#
#                                      med2018  \
# 0           Quality Correctional Health Care
# 1                   Southern Health Partners
# 3                                     public
# 4           Advanced Correctional Healthcare
# 5                                     public
# 6                   Southern Health Partners
# 7           Advanced Correctional Healthcare
# 8                             NaphCare, Inc.
# 9           Quality Correctional Health Care
# 10          Quality Correctional Health Care
# 11          Quality Correctional Health Care
# 12  Whatley Health Services (Tuscaloosa, AL)
# 14                                    public
# 17                                  Wellpath
# 18                                    public
# 20                    Wexford Health Sources
# 21                                    public
# 22                    Wexford Health Sources
# 23                                  Wellpath
# 24                                transition
# 25                           Turn-Key Health
# 26                                    public
# 27                                    public
# 28                                    public
# 29                  Southern Health Partners
# 30                           Turn-Key Health
# 31                                    public
# 32                Karas Correctional Health
# 34                                  Wellpath
# 35                                  Wellpath
#
#                                      med2019
# 0           Quality Correctional Health Care
# 1                   Southern Health Partners
# 3                                     public
# 4           Advanced Correctional Healthcare
# 5                                     public
# 6                   Southern Health Partners
# 7                                 transition
# 8                             NaphCare, Inc.
# 9           Quality Correctional Health Care
# 10          Quality Correctional Health Care
# 11                                transition
# 12  Whatley Health Services (Tuscaloosa, AL)
# 14                                    public
# 17                                  Wellpath
# 18                                    public
# 20                    Wexford Health Sources
# 21                                    public
# 22                    Wexford Health Sources
# 23                                  Wellpath
# 24                           Turn-Key Health
# 25                           Turn-Key Health
# 26                                    public
# 27                                    public
# 28                                    public
# 29                  Southern Health Partners
# 30                           Turn-Key Health
# 31                                transition
# 32                Karas Correctional Health
# 34                                  Wellpath
# 35                                  Wellpath
#
# [30 rows x 116 columns]

# %%
df['med2008'] = np.where(~df['med2008'].str.contains("public|transition"), "private", df['med2008'])
df['med2009'] = np.where(~df['med2009'].str.contains("public|transition"), "private", df['med2009'])
df['med2010'] = np.where(~df['med2010'].str.contains("public|transition"), "private", df['med2010'])
df['med2011'] = np.where(~df['med2011'].str.contains("public|transition"), "private", df['med2011'])
df['med2012'] = np.where(~df['med2012'].str.contains("public|transition"), "private", df['med2012'])
df['med2013'] = np.where(~df['med2013'].str.contains("public|transition"), "private", df['med2013'])
df['med2014'] = np.where(~df['med2014'].str.contains("public|transition"), "private", df['med2014'])
df['med2015'] = np.where(~df['med2015'].str.contains("public|transition"), "private", df['med2015'])
df['med2016'] = np.where(~df['med2016'].str.contains("public|transition"), "private", df['med2016'])
df['med2017'] = np.where(~df['med2017'].str.contains("public|transition"), "private", df['med2017'])
df['med2018'] = np.where(~df['med2018'].str.contains("public|transition"), "private", df['med2018'])
df['med2019'] = np.where(~df['med2019'].str.contains("public|transition"), "private", df['med2019'])
# Out:
# <ipython-input-136-68ccc1cf6eca>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['med2008'] = np.where(~df['med2008'].str.contains("public|transition"), "private", df['med2008'])
# <ipython-input-136-68ccc1cf6eca>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['med2009'] = np.where(~df['med2009'].str.contains("public|transition"), "private", df['med2009'])
# <ipython-input-136-68ccc1cf6eca>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['med2010'] = np.where(~df['med2010'].str.contains("public|transition"), "private", df['med2010'])
# <ipython-input-136-68ccc1cf6eca>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['med2011'] = np.where(~df['med2011'].str.contains("public|transition"), "private", df['med2011'])
# <ipython-input-136-68ccc1cf6eca>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['med2012'] = np.where(~df['med2012'].str.contains("public|transition"), "private", df['med2012'])
# <ipython-input-136-68ccc1cf6eca>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['med2013'] = np.where(~df['med2013'].str.contains("public|transition"), "private", df['med2013'])
# <ipython-input-136-68ccc1cf6eca>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['med2014'] = np.where(~df['med2014'].str.contains("public|transition"), "private", df['med2014'])
# <ipython-input-136-68ccc1cf6eca>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['med2015'] = np.where(~df['med2015'].str.contains("public|transition"), "private", df['med2015'])
# <ipython-input-136-68ccc1cf6eca>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['med2016'] = np.where(~df['med2016'].str.contains("public|transition"), "private", df['med2016'])
# <ipython-input-136-68ccc1cf6eca>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['med2017'] = np.where(~df['med2017'].str.contains("public|transition"), "private", df['med2017'])
# <ipython-input-136-68ccc1cf6eca>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['med2018'] = np.where(~df['med2018'].str.contains("public|transition"), "private", df['med2018'])
# <ipython-input-136-68ccc1cf6eca>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['med2019'] = np.where(~df['med2019'].str.contains("public|transition"), "private", df['med2019'])

# %%
df.head(21)
# Out:
#     id    fips statecode     state state_notes      county  \
# 0    1  1003.0        AL   Alabama         NaN     Baldwin
# 1    2  1015.0        AL   Alabama         NaN     Calhoun
# 3    4  1069.0        AL   Alabama         NaN     Houston
# 4    5  1073.0        AL   Alabama         NaN   Jefferson
# 5   13  1081.0        AL   Alabama         NaN         Lee
# 6    7  1089.0        AL   Alabama         NaN     Madison
# 7    8  1095.0        AL   Alabama         NaN    Marshall
# 8    9  1097.0        AL   Alabama         NaN      Mobile
# 9    6  1101.0        AL   Alabama         NaN  Montgomery
# 10  10  1103.0        AL   Alabama         NaN      Morgan
# 11  11  1117.0        AL   Alabama         NaN      Shelby
# 12  12  1125.0        AL   Alabama         NaN  Tuscaloosa
# 14  15  4005.0        AZ   Arizona         NaN    Coconino
# 17  18  4015.0        AZ   Arizona         NaN      Mohave
# 18  19  4017.0        AZ   Arizona         NaN      Navajo
# 20  21  4021.0        AZ   Arizona         NaN       Pinal
# 21  22  4023.0        AZ   Arizona         NaN  Santa Cruz
# 22  23  4025.0        AZ   Arizona         NaN     Yavapai
# 23  24  4027.0        AZ   Arizona         NaN        Yuma
# 24  25  5007.0        AR  Arkansas         NaN      Benton
# 25  26  5031.0        AR  Arkansas         NaN   Craighead
#
#                                                  jail  \
# 0                         Baldwin County Corr. Center
# 1                                 Calhoun County Jail
# 3                                 Houston County Jail
# 4                    Jefferson County Birmingham Jail
# 5                    W.S. Buck Jones Detention Center
# 6                   Madison County Detention Facility
# 7                                Marshall County Jail
# 8                            Mobile County Metro Jail
# 9   Mac Sim Butler Montgomery County Detention Fac...
# 10                       Morgan County Corr. Facility
# 11                                 Shelby County Jail
# 12                             Tuscaloosa County Jail
# 14                               Coconino County Jail
# 17             Mohave County Adult Detention Facility
# 18                     Navajo County Detention Center
# 20                                  Pinal County Jail
# 21           Santa Cruz County Adult Detention Center
# 22                 Yavapai County Camp Verde Facility
# 23                       Yuma County Detention Center
# 24                   Benton County Detention Facility
# 25                  Craighead County Detention Center
#
#                                            jail_notes  d2008  d2009  ...  \
# 0                                                 NaN    0.0    0.0  ...
# 1                                                 NaN    0.0    1.0  ...
# 3                                                 NaN    1.0    0.0  ...
# 4   ADP for 2008 was based on data provided by the...    NaN    NaN  ...
# 5                                                 NaN    0.0    0.0  ...
# 6                ADP for 2019 averaged from 2016-2018    0.0    0.0  ...
# 7                                                 NaN    0.0    2.0  ...
# 8                                                 NaN    0.0    1.0  ...
# 9                                                 NaN    0.0    0.0  ...
# 10                                                NaN    0.0    0.0  ...
# 11                                                NaN    3.0    0.0  ...
# 12                                                NaN    0.0    0.0  ...
# 14                                                NaN    0.0    0.0  ...
# 17           ADP for 2018 averaged from 2016 and 2017    0.0    1.0  ...
# 18                                                NaN    0.0    0.0  ...
# 20                                                NaN    3.0    1.0  ...
# 21                                                NaN    0.0    0.0  ...
# 22                                                NaN    0.0    1.0  ...
# 23                                                NaN    0.0    0.0  ...
# 24                                                NaN    0.0    0.0  ...
# 25                                                NaN    0.0    0.0  ...
#
#        med2010     med2011  med2012  med2013     med2014     med2015  \
# 0       public      public   public   public      public      public
# 1       public      public   public   public      public  transition
# 3       public      public   public   public      public      public
# 4      private  transition  private  private     private     private
# 5       public      public   public   public      public      public
# 6      private     private  private  private     private  transition
# 7      private     private  private  private     private  transition
# 8      private     private  private  private     private     private
# 9      private     private  private  private     private     private
# 10     private     private  private  private     private  transition
# 11     private     private  private  private  transition     private
# 12     private     private  private  private     private     private
# 14      public      public   public   public      public      public
# 17     private     private  private  private  transition     private
# 18      public      public   public   public      public      public
# 20      public      public   public   public      public      public
# 21      public      public   public   public      public      public
# 22     private     private  private  private     private     private
# 23     private     private  private  private     private     private
# 24      public      public   public   public  transition     private
# 25  transition     private  private  private     private     private
#
#        med2016     med2017     med2018     med2019
# 0   transition     private     private     private
# 1      private  transition     private     private
# 3       public      public      public      public
# 4      private     private     private     private
# 5       public      public      public      public
# 6      private     private     private     private
# 7      private     private     private  transition
# 8      private     private     private     private
# 9      private     private     private     private
# 10     private     private     private     private
# 11     private     private     private  transition
# 12     private     private     private     private
# 14      public      public      public      public
# 17     private     private     private     private
# 18      public      public      public      public
# 20      public  transition     private     private
# 21      public      public      public      public
# 22     private     private     private     private
# 23     private     private     private     private
# 24     private     private  transition     private
# 25     private  transition     private     private
#
# [21 rows x 116 columns]
