# %%
import pandas as pd
# Out:
# /Users/rachelspring/.pyenv/versions/3.9.1/lib/python3.9/site-packages/pandas/compat/__init__.py:97: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
deaths_df = pd.read_csv("all_deaths.csv")

# %%
jails_df = pd.read_csv("all_jails.csv")

# %%
values={'med2008':'Unknown', 'med2009':'Unknown', 'med2010':'Unknown', 'med2011':'Unknown', 'med2012':'Unknown', 'med2013':'Unknown', 'med2014':'Unknown', 'med2015':'Unknown', 'med2016':'Unknown', 'med2017':'Unknown', 'med2018':'Unknown','med2019':'Unknown'}

# %%
df=jails_df.fillna(value=values)
df.head(42)
# Out:
#      id    fips statecode       state  \
# 0     1  1003.0        AL     Alabama
# 1     2  1015.0        AL     Alabama
# 2     3  1055.0        AL     Alabama
# 3     4  1069.0        AL     Alabama
# 4     5  1073.0        AL     Alabama
# 5    13  1081.0        AL     Alabama
# 6     7  1089.0        AL     Alabama
# 7     8  1095.0        AL     Alabama
# 8     9  1097.0        AL     Alabama
# 9     6  1101.0        AL     Alabama
# 10   10  1103.0        AL     Alabama
# 11   11  1117.0        AL     Alabama
# 12   12  1125.0        AL     Alabama
# 13   14  4003.0        AZ     Arizona
# 14   15  4005.0        AZ     Arizona
# 15   16  4007.0        AZ     Arizona
# 16   17  4013.0        AZ     Arizona
# 17   18  4015.0        AZ     Arizona
# 18   19  4017.0        AZ     Arizona
# 19   20  4019.0        AZ     Arizona
# 20   21  4021.0        AZ     Arizona
# 21   22  4023.0        AZ     Arizona
# 22   23  4025.0        AZ     Arizona
# ...

# %%
df['med2008'] = df.med2008.str.replace(r'(^.*/.*$)', 'transition')
# Out:
# <ipython-input-51-274a4404e917>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['med2008'] = df.med2008.str.replace(r'(^.*/.*$)', 'transition')

# %%
df['med2009'] = df.med2009.str.replace(r'(^.*/.*$)', 'transition')
# Out:
# <ipython-input-53-38c67a994687>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['med2009'] = df.med2009.str.replace(r'(^.*/.*$)', 'transition')

# %%
df['med2010'] = df.med2010.str.replace(r'(^.*/.*$)', 'transition')
# Out:
# <ipython-input-54-4fa9760053aa>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['med2010'] = df.med2010.str.replace(r'(^.*/.*$)', 'transition')

# %%
df['med2011'] = df.med2011.str.replace(r'(^.*/.*$)', 'transition')
# Out:
# <ipython-input-56-b81200522965>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['med2011'] = df.med2011.str.replace(r'(^.*/.*$)', 'transition')

# %%
df['med2012'] = df.med2012.str.replace(r'(^.*/.*$)', 'transition')
# Out:
# <ipython-input-57-d387f10065cd>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['med2012'] = df.med2012.str.replace(r'(^.*/.*$)', 'transition')

# %%
df['med2013'] = df.med2013.str.replace(r'(^.*/.*$)', 'transition')
# Out:
# <ipython-input-58-5e678d2b9ab9>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['med2013'] = df.med2013.str.replace(r'(^.*/.*$)', 'transition')

# %%
df['med2014'] = df.med2014.str.replace(r'(^.*/.*$)', 'transition')
# Out:
# <ipython-input-60-bb77168b3b39>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['med2014'] = df.med2014.str.replace(r'(^.*/.*$)', 'transition')

# %%
df['med2015'] = df.med2015.str.replace(r'(^.*/.*$)', 'transition')
# Out:
# <ipython-input-61-babcf169ef85>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['med2015'] = df.med2015.str.replace(r'(^.*/.*$)', 'transition')

# %%
df['med2016'] = df.med2016.str.replace(r'(^.*/.*$)', 'transition')
# Out:
# <ipython-input-62-b1a6cbc9b40e>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['med2016'] = df.med2016.str.replace(r'(^.*/.*$)', 'transition')

# %%
df['med2017'] = df.med2017.str.replace(r'(^.*/.*$)', 'transition')
# Out:
# <ipython-input-63-80b7927779ae>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['med2017'] = df.med2017.str.replace(r'(^.*/.*$)', 'transition')

# %%
df['med2018'] = df.med2018.str.replace(r'(^.*/.*$)', 'transition')
# Out:
# <ipython-input-64-355b8a5ed64f>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['med2018'] = df.med2018.str.replace(r'(^.*/.*$)', 'transition')

# %%
df['med2019'] = df.med2019.str.replace(r'(^.*/.*$)', 'transition')
# Out:
# <ipython-input-65-dd9a4a492742>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['med2019'] = df.med2019.str.replace(r'(^.*/.*$)', 'transition')

# %%
df.head()
# Out:
#    id    fips statecode    state state_notes     county  \
# 0   1  1003.0        AL  Alabama         NaN    Baldwin
# 1   2  1015.0        AL  Alabama         NaN    Calhoun
# 2   3  1055.0        AL  Alabama         NaN     Etowah
# 3   4  1069.0        AL  Alabama         NaN    Houston
# 4   5  1073.0        AL  Alabama         NaN  Jefferson
#
#                                jail  \
# 0       Baldwin County Corr. Center
# 1               Calhoun County Jail
# 2    Etowah County Detention Center
# 3               Houston County Jail
# 4  Jefferson County Birmingham Jail
#
#                                           jail_notes  d2008  d2009  ...  \
# 0                                                NaN    0.0    0.0  ...
# 1                                                NaN    0.0    1.0  ...
# 2                                                NaN    0.0    0.0  ...
# 3                                                NaN    1.0    0.0  ...
# ...

# %%
import numpy as np

# %%
df['med2008'] = np.where(~df['med2008'].str.contains("public"), "private", df['med2008'])
df['med2009'] = np.where(~df['med2009'].str.contains("public"), "private", df['med2009'])
df['med2010'] = np.where(~df['med2010'].str.contains("public"), "private", df['med2010'])
df['med2011'] = np.where(~df['med2011'].str.contains("public"), "private", df['med2011'])
df['med2012'] = np.where(~df['med2012'].str.contains("public"), "private", df['med2012'])
df['med2013'] = np.where(~df['med2013'].str.contains("public"), "private", df['med2013'])
df['med2014'] = np.where(~df['med2014'].str.contains("public"), "private", df['med2014'])
df['med2015'] = np.where(~df['med2015'].str.contains("public"), "private", df['med2015'])
df['med2016'] = np.where(~df['med2016'].str.contains("public"), "private", df['med2016'])
df['med2017'] = np.where(~df['med2017'].str.contains("public"), "private", df['med2017'])
df['med2018'] = np.where(~df['med2018'].str.contains("public"), "private", df['med2018'])
df['med2019'] = np.where(~df['med2019'].str.contains("public"), "private", df['med2019'])

# %%
df.head()
# Out:
#    id    fips statecode    state state_notes     county  \
# 0   1  1003.0        AL  Alabama         NaN    Baldwin
# 1   2  1015.0        AL  Alabama         NaN    Calhoun
# 2   3  1055.0        AL  Alabama         NaN     Etowah
# 3   4  1069.0        AL  Alabama         NaN    Houston
# 4   5  1073.0        AL  Alabama         NaN  Jefferson
#
#                                jail  \
# 0       Baldwin County Corr. Center
# 1               Calhoun County Jail
# 2    Etowah County Detention Center
# 3               Houston County Jail
# 4  Jefferson County Birmingham Jail
#
#                                           jail_notes  d2008  d2009  ...  \
# 0                                                NaN    0.0    0.0  ...
# 1                                                NaN    0.0    1.0  ...
# 2                                                NaN    0.0    0.0  ...
# 3                                                NaN    1.0    0.0  ...
# ...
